# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Does the player ratings match their predicted potential?
#     - hypothesis: Player ratings are positively correlated with their potential
# # Does age correlate with player ratings/potential?
#     - H: age negatively correlates with both of these attributes
# # How does player nationality compare to potential?

# %%
# Viewing the dataset
players = pd.read_csv("FIFA-21 Complete.csv", delimiter=";")
print(players)
# Out:
#        player_id               name  nationality  position  overall  age  \
# 0         158023       Lionel Messi    Argentina  ST|CF|RW       94   33
# 1          20801  Cristiano Ronaldo     Portugal     ST|LW       93   35
# 2         190871          Neymar Jr       Brazil    CAM|LW       92   28
# 3         203376    Virgil van Dijk  Netherlands        CB       91   29
# 4         200389          Jan Oblak     Slovenia        GK       91   27
# ...          ...                ...          ...       ...      ...  ...
# 17976     256093        Jaime Ortíz      Ecuador        ST       56   21
# 17977     256088   Michael Carcelén      Ecuador        CM       56   23
# 17978     256074        Davide Luzi    Venezuela        ST       56   18
# 17979     256073    Sergio Sulbarán    Venezuela        RW       56   22
# 17980     256072          Luis Peña    Venezuela        CM       56   18
#
#        hits  potential                         team
# ...

# %%
# Histograms for [overall, age, hits, potential]
# sns.countplot(data=players, x="age")
# sns.countplot(data=players, x="overall")
# sns.countplot(data=players, x="hits")
sns.countplot(data=players, x="potential")
plt.show()
